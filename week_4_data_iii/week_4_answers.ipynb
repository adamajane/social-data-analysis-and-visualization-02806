# %% [markdown]
# # Part 1: More on Data Visualization
#
# Check the note book [Week 4 exercises](/Users/Adam/VSCodeProjects/social-data-analysis-and-visualization-02806/week_4_data_iii/week_4_exercises.ipynb)

# %% [markdown]
# ## Part 2: Exploratory data visualization with Two Variables
